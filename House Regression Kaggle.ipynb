# %%
import pandas as pd
import numpy as np
# from sklearn.preprocessing  
from sklearn.ensemble import RandomForestRegressor
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
df = pd.read_csv("train.csv")

# We could use random forest regression for this house regression
random_forest = RandomForestRegressor()

# %%
# Fill in missing data, we can use mean imputation for the missing data for LotFrontage
# For the MSZoning Categories, we can implement One-Hot Encoding, since the dataset is small
imputer = SimpleImputer()


X = df.drop(columns="SalePrice", axis=1)
y = df["SalePrice"]

X_train, X_test, y_train, y_test = train_test_split(X,y)
X_train_without_object = X_train.select_dtypes(exclude="object")
X_test_without_object = X_test.select_dtypes(exclude="object")


imputed_X_train = pd.DataFrame(imputer.fit_transform(X_train_without_object))
imputed_X_train.columns = X_train_without_object.columns

imputed_X_test = pd.DataFrame(imputer.fit_transform(X_test_without_object))
imputed_X_test.columns = X_test_without_object.columns

imputed_X_train
# Out:
#           Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0     1291.0        80.0    69.471508  14112.0          5.0          7.0
# 1      562.0        20.0    77.000000  10010.0          5.0          5.0
# 2        5.0        60.0    84.000000  14260.0          8.0          5.0
# 3      463.0        20.0    60.000000   8281.0          5.0          5.0
# 4      887.0        90.0    70.000000   8393.0          5.0          5.0
# ...      ...         ...          ...      ...          ...          ...
# 1090  1067.0        60.0    59.000000   7837.0          6.0          7.0
# 1091  1010.0        50.0    60.000000   6000.0          5.0          5.0
# 1092   410.0        60.0    85.000000  10800.0          8.0          5.0
# 1093   385.0        60.0    69.471508  53107.0          6.0          5.0
# 1094   287.0        50.0    77.000000   9786.0          6.0          7.0
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  GarageArea  \
# ...

# %%
label_encoder = LabelEncoder()

X_train_with_object = X_train.select_dtypes(include="object")
columns_with_missing_data = [col for col in X_train_with_object.columns if X_train_with_object[col].isnull().any()]
X_train_with_object = X_train_with_object.drop(columns=columns_with_missing_data)

X_train_label_encoded = pd.DataFrame(label_encoder.fit_transform(X_train_with_object))


# X_train.groupby("MSZoning").LotFrontage.max().sort_index()
# X_train.isnull().any()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [52], in <cell line: 7>()
#       4 columns_with_missing_data = [col for col in X_train_with_object.columns if X_train_with_object[col].isnull().any()]
#       5 X_train_with_object = X_train_with_object.drop(columns=columns_with_missing_data)
# ----> 7 X_train_label_encoded = pd.DataFrame(label_encoder.fit_transform(X_train_with_object))
#
# File ~\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:115, in LabelEncoder.fit_transform(self, y)
#     102 def fit_transform(self, y):
#     103     """Fit label encoder and return encoded labels.
#     104
#     105     Parameters
#    (...)
#     113         Encoded labels.
#     114     """
# --> 115     y = column_or_1d(y, warn=True)
#     116     self.classes_, y = _unique(y, return_inverse=True)
#     117     return y
#
# ...
